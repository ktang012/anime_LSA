# %% [markdown]
# ## Preprocess the data
# - Tokenize
# - Get rid of punctuations... maybe keep hashtags, emoticons?
# - Remove numbers, links, stopwords
# - Convert uppercase to lowercase

# %%
import os
import re
import json
import pprint

from nltk.tokenize import TweetTokenizer
from nltk.stem.porter import *

tweet_tok = TweetTokenizer()
port_stem = PorterStemmer()

sample_comments_path = os.path.join("..","data","spring_2017",
                               "boku_no_hero_academia_2nd_season",
                               "ep_1.json")

# %%
discussion_thread = json.load(open(sample_comments_path))

# %%
# Will need to find a better stop word removal method
# Use this for now
stop_words = [
    "a", "above", "all", "am", "an", "and", "any", "are", "as", "at",
    "be", "been", "but", "by",
    "can", "could",
    "did", "do", "does",
    "each",
    "few", "for", "from",
    "had", "has", "have", "he", "her", "here", "him","himself", "his", "how",
    "i", "if", "in", "is", "it", "its", "itself",
    "just",
    "let",
    "me", "my", "myself",
    "no", "nor",
    "of", "off", "on", "once", "only", "or", "our", "ourselves", "out",
    "she", "so", "such",
    "than", "that", "the", "their", "them", "then", "they", "this", "those", "to", "too",
    "under", "up",
    "very",
    "was", "we", "what", "when", "where", "who", "why", "with", "would",
    "you", "your", "yourself"    
]

# How to exploit emoticons? For now discard all non-characters
symbols = ["!", "@", "#", "$", "%", "^", "&", "*", "(", ")", "-", "=",
           "1", "2", "3", "4", "5", "6", "7", "8", "9", "0", "_", "+",
           "<", ">", ",", ".", "\"", "'", "?", "/", "\\", ";", ":","~",
           "`"]

# How to detect if the token is a combination of non-characters?
# Want to remove non-alpha characters
# https://stackoverflow.com/questions/1276764/stripping-everything-but-alphanumeric-chars-from-a-string-in-python
# Note: See 1st answer, 2nd comment
non_alpha_pattern = "[^a-zA-Z]+"

# How to detect if it's a link?
# Don't delete link... make the link a feature?
link_pattern = "http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+"

# %%
discussion_links = []
preprocessed_comments = []
for comment in discussion_thread["comments"]:
    tokenized_comment = tweet_tok.tokenize(comment["text"])

    preprocessed_comment = []
    for tok in tokenized_comment:
        if re.match(link_pattern, tok):
            discussion_links.append(tok)
        else:
            if len(tok) <= 2:
                continue
            elif tok in stop_words:
                continue
            else:
                preprocessed_comment.append(tok.lower())

    preprocessed_comment = [port_stem.stem(tok) for tok in preprocessed_comment]
    preprocessed_comment = [re.sub(non_alpha_pattern, "", tok) for tok in preprocessed_comment]

    clean_comment = []
    for tok in preprocessed_comment:
        if len(tok) <= 2:
            continue
        elif tok in stop_words:
            continue
        else:
            clean_comment.append(tok)

    preprocessed_comments.append(clean_comment)


pprint.pprint(preprocessed_comments)
# pprint.pprint(discussion_links)
# Out:
# [['midnight',
#   'fangirl',
#   'over',
#   'hero',
#   'name',
#   'ador',
#   'best',
#   'frog',
#   'now',
#   'best',
#   'froppi'],
#  ['froppi', 'life'],
#  ['frog', 'girl', 'best', 'girl', 'hail', 'froppi'],
#  ['fropsday', 'dude'],
#  ['best', 'frog', 'alway', 'froppi', 'taken', 'until', 'now', 'rest', 'find'],
#  ['get', 'sloppi', 'froppi'],
#  [],
#  ['youv', 'wait', 'month', 'post', 'havent'],
#  ['more', 'like', 'save', 'forgot', 'about', 'until', 'now'],
#  ['yiss', 'mutha', 'fuckin', 'froppi'],
#  ['wait',
#   'midoriya',
#   'name',
#   'right',
#   'deku',
#   'probabl',
#   'best',
#   'learn',
#   'use',
#   'quirk'],
#  ['expect', 'name', 'plu', 'ultra'],
#  ['think', 'some', 'might'],
#  ['alt', 'right', 'tho'],
#  ['dont',
#   'blame',
#   'uraraka',
#   'call',
#   'turd',
#   'blossom',
#   'becaus',
#   'thought',
#   'cute',
#   'tell',
#   'agenc',
#   'make',
#   'poster',
#   'size',
#   'build',
#   'turd',
#   'blossom'],
#  ['right', 'except', 'hed', 'say', 'light'],
#  [],
#  ['honestli', 'expect', 'name', 'one'],
#  ['hero',
#   'name',
#   'might',
#   'suitabl',
#   'midoriya',
#   'hero',
#   'will',
#   'right',
#   'coz',
#   'now'],
#  ['realli', 'feel', 'like', 'absolut', 'madman', 'fit', 'best'],
#  ['hope', 'also', 'mighti'],
#  ['thi', 'wouldv', 'great', 'name'],
#  ['mostli', 'mayb'],
#  ['midodaijobu'],
#  ['hardest', 'time', 'read', 'dont', 'know'],
#  ['alt', 'right'],
#  ['alt', 'might', 'best', 'muscl'],
#  ['basi', 'lol'],
#  ['remov'],
#  ['man', 'believ'],
#  ['delet'],
#  ['mean', 'agre'],
#  ['not', 'entir', 'sure', 'about', 'not', 'get', 'polit'],
#  ['delet'],
#  ['didnt',
#   'actual',
#   'know',
#   'whether',
#   'polit',
#   'not',
#   'henc',
#   'ask',
#   'first',
#   'place'],
#  ['bro',
#   'think',
#   'most',
#   'peopl',
#   'see',
#   'differ',
#   'between',
#   'right',
#   'nazi',
#   'same',
#   'peopl',
#   'see',
#   'differ',
#   'between',
#   'liber',
#   'easili',
#   'offend',
#   'kid'],
#  ['delet'],
#  ['pleas',
#   'educ',
#   'matter',
#   'see',
#   'differ',
#   'between',
#   'alt',
#   'right',
#   'nazi'],
#  ['delet'],
#  ['free',
#   'speech',
#   'lol',
#   'good',
#   'joke',
#   'hope',
#   'aint',
#   'subreddit',
#   'everyon',
#   'disagre',
#   'ban'],
#  ['delet'],
#  ['alt',
#   'right',
#   'old',
#   'name',
#   'use',
#   'fascism',
#   'white',
#   'supremacist',
#   'make',
#   'america',
#   'great',
#   'again'],
#  ['alt',
#   'right',
#   'attempt',
#   'rebrand',
#   'neonazi',
#   'other',
#   'similar',
#   'ideolog',
#   'hilari',
#   'get',
#   'pissi',
#   'about',
#   'polit',
#   'correct',
#   'about',
#   'name'],
#  ['america',
#   'altright',
#   'term',
#   'associ',
#   'far',
#   'right',
#   'persuas',
#   'which',
#   'certainti',
#   'compar',
#   'fascism',
#   'nazism'],
#  ['make', 'name', 'even', 'better', 'thank'],
#  ['also', 'catch', 'term', 'peopl', 'disagre'],
#  ['well',
#   'actual',
#   'alt',
#   'right',
#   'facist',
#   'mysogonist',
#   'white',
#   'supremisist',
#   'ideolog',
#   'deserv',
#   'especi',
#   'consid',
#   'some',
#   'dumb',
#   'attempt',
#   'rebrand',
#   'timeless',
#   'classic',
#   'ideolog',
#   'like',
#   'said',
#   'hilari',
#   'watch',
#   'peopl',
#   'get',
#   'pissi',
#   'about',
#   'polit',
#   'correct',
#   'word',
#   'altright'],
#  ['dont',
#   'disagre',
#   'hear',
#   'someth',
#   'fring',
#   'group',
#   'like',
#   'alt',
#   'right',
#   'mainstream',
#   'annoy',
#   'not',
#   'big',
#   'left',
#   'claim',
#   'say',
#   'more',
#   'more',
#   'peopl',
#   'altright',
#   'legitim',
#   'group',
#   'one',
#   'want'],
#  ['yeah',
#   'agre',
#   'there',
#   'two',
#   'thing',
#   'should',
#   'keep',
#   'mind',
#   'these',
#   'peopl',
#   'legitim',
#   'believ',
#   'infact',
#   'grow',
#   'past',
#   'proven',
#   'cant',
#   'passiv',
#   'expect',
#   'ideolog',
#   'die',
#   'requir',
#   'effort'],
#  ['cri', 'laugh'],
#  ['fear', 'altright'],
#  ['instead', 'save', 'peopl', 'crimin', 'save', 'illeg', 'immigr'],
#  ['fear', 'intensifi'],
#  ['bare', 'might'],
#  ['someday', 'might'],
#  ['perhap'],
#  ['think', 'small', 'might'],
#  ['mite', 'goto'],
#  ['some', 'might'],
#  ['nah',
#   'call',
#   'might',
#   'younger',
#   'version',
#   'briefli',
#   'saw',
#   'flashback',
#   'episod',
#   'ago',
#   'some',
#   'peopl',
#   'use',
#   'small',
#   'might',
#   'might',
#   'weaken',
#   'form',
#   'well',
#   'prefer',
#   'mini',
#   'might',
#   'one'],
#  ['call', 'night'],
#  ['call', 'weak', 'form', 'skelat'],
#  ['call',
#   'form',
#   'actual',
#   'name',
#   'idk',
#   'manga',
#   'spoiler',
#   'case',
#   'toshinori',
#   'yagi'],
#  ['current',
#   'manga',
#   'spoiler',
#   'gran',
#   'torino',
#   'say',
#   'dure',
#   'preview',
#   'offici',
#   'reveal',
#   'next',
#   'episod'],
#  ['seem', 'recal', 'also', 'said', 'dure', 'season'],
#  ['some',
#   'peopl',
#   'use',
#   'small',
#   'might',
#   'might',
#   'weaken',
#   'form',
#   'well',
#   'prefer',
#   'mini',
#   'might',
#   'one',
#   'call',
#   'form',
#   'might'],
#  ['right', 'hilari'],
#  ['plu', 'ordinari'],
#  ['deku', 'now', 'pro', 'hero', 'enter', 'scene', 'destruct', 'might', 'now'],
#  ['tri', 'meme', 'arrow', 'fail'],
#  ['mate', 'take', 'more', 'advanc', 'format', 'way'],
#  ['should', 'use', 'instead'],
#  ['never',
#   'heard',
#   'call',
#   'meme',
#   'arrow',
#   'befor',
#   'alway',
#   'greentext',
#   'quot',
#   'arrow'],
#  ['perhap', 'more', 'familiar', 'name', 'comedi', 'chevron'],
#  ['absolut', 'not', 'dig'],
#  ['man',
#   'chose',
#   'name',
#   'hed',
#   'enter',
#   'scene',
#   'say',
#   'like',
#   'matthew',
#   'mcconaughey'],
#  ['without', 'spoil', 'anyth', 'manga', 'ill', 'say', 'may', 'get', 'wish'],
#  ['think',
#   'more',
#   'jim',
#   'carrey',
#   'entranc',
#   'wouldnt',
#   'fit',
#   'deku',
#   'person',
#   'though'],
#  ['say', 'like', 'matthew', 'mcconaughey', 'refer'],
#  ['king', 'explos', 'murder', 'exploit'],
#  ['see', 'kona', 'dio', 'mashup', 'come'],
#  ['midnight', 'think', 'best', 'name'],
#  ['shine'],
#  ['obligatori'],
#  ['still', 'cant', 'get', 'over', 'deku', 'quirk'],
#  ['hmmm', 'name', 'should', 'choos'],
#  ['thi', 'danger'],
#  ['great', 'power', 'come', 'great', 'wait', 'wrong', 'superhero', 'franchis'],
#  ['obviou', 'one'],
#  ['recurs', 'classic'],
#  ['waga', 'bakugo', 'insert', 'stolen'],
#  ['exphurosiooon'],
#  ['lol', 'bakugo', 'chuuni', 'speak', 'like', 'megumin', 'ill', 'wish', 'like'],
#  ['done',
#   'edit',
#   'got',
#   'bore',
#   'updat',
#   'version',
#   'much',
#   'cooler',
#   'hero',
#   'name',
#   'sign',
#   'join',
#   'aclass',
#   'hero',
#   'agenc',
#   'bonu',
#   'crappi',
#   'cutout',
#   'bakugo',
#   'pleas',
#   'edit',
#   'now',
#   'almost',
#   'cant',
#   'sleep',
#   'more',
#   'base',
#   'fdpboota',
#   'suggest',
#   'everyth',
#   'diejoubu',
#   'everyth',
#   'diejouboom'],
#  ['anim', 'not', 'mistak'],
#  ['font'],
#  ['googl', 'scribbl', 'font', 'found'],
#  ['look', 'like', 'someon', 'blast', 'heheheh', 'nice', 'sing', 'sheet', 'btw'],
#  ['aaaaaand', 'save', 'look', 'forward', 'see', 'use', 'futur'],
#  ['sign', 'join', 'aclass', 'hero', 'agenc', 'sure', 'name', 'written', 'like'],
#  ['best', 'show', 'past', 'season', 'realli', 'want', 'episod', 'season'],
#  ['need', 'albumbot'],
#  ['ill',
#   'admit',
#   'made',
#   'laugh',
#   'bakugou',
#   'angri',
#   'face',
#   'realli',
#   'sell'],
#  ['next', 'everyth', 'diejoubu', 'everyth', 'diejouboom'],
#  ['everyth', 'diejouboom', 'ohh', 'wow', 'gotta', 'one'],
#  ['made', 'these', 'everyth', 'diejoubu', 'everyth', 'diejouboom'],
#  ['grouphug'],
#  ['shoutout', 'whoever', 'post', 'animeirl', 'animem', 'fuck', 'know', 'els'],
#  ['dead',
#   'aliv',
#   'aliv',
#   'perfect',
#   'also',
#   'glad',
#   'eraserhead',
#   'present',
#   'mic',
#   'flashback',
#   'omak',
#   'littl',
#   'midoriya',
#   'pick',
#   'name',
#   'scene',
#   'nice',
#   'get',
#   'surpris',
#   'like',
#   'manga',
#   'reader'],
#  ['aliv', 'reaction', 'didnt', 'chang', 'love', 'hahaha'],
#  ['find',
#   'hilari',
#   'present',
#   'mic',
#   'eras',
#   'head',
#   'were',
#   'friend',
#   'even',
#   'way',
#   'back',
#   'person',
#   'backward',
#   'other',
#   'funni',
#   'love',
#   'see',
#   'more',
#   'back',
#   'school'],
#  ['loos', 'definit', 'friend', 'youd', 'call', 'relationship', 'friendship'],
#  ['probabl',
#   'care',
#   'about',
#   'there',
#   'power',
#   'use',
#   'name',
#   'given',
#   'someon',
#   'els'],
#  ['assum', 'happen', 'sit', 'next', 'other', 'class', 'not', 'friend'],
#  ['tendenc',
#   'make',
#   'friend',
#   'peopl',
#   'complet',
#   'opposit',
#   'later',
#   'seri',
#   'see',
#   'friend',
#   'girl',
#   'power',
#   'make',
#   'peopl',
#   'laugh',
#   'hyster',
#   'teacher',
#   'anoth',
#   'school',
#   'make',
#   'bad',
#   'joke',
#   'tri',
#   'flirt',
#   'eraserhead',
#   'not',
#   'amus',
#   'youd',
#   'expect'],
#  ['spoiler', 'mayb', 'doesnt', 'realli', 'spoil', 'anyth', 'futur', 'chapter'],
#  ['doesnt',
#   'realli',
#   'spoil',
#   'anyth',
#   'day',
#   'havent',
#   'report',
#   'taken',
#   'down',
#   'mod',
#   'probabl',
#   'basic',
#   'relev',
#   'plot'],
#  ['true'],
#  ['sound', 'like', 'otp'],
#  ['cameod',
#   'tournament',
#   'arc',
#   'actual',
#   'longer',
#   'rememb',
#   'which',
#   'episod',
#   'though'],
#  ['pretti', 'shit', 'power', 'wasnt', 'even', 'amus'],
#  ['think', 'like', 'make', 'laugh', 'wont', 'abl', 'stop'],
#  ['nah', 'make', 'spontan', 'laugh', 'eraserhead', 'eras', 'wont', 'laugh'],
#  ['deactiv', 'quirk', 'wont', 'laugh'],
#  ['forgot', 'quirk'],
#  ['dont',
#   'mind',
#   'spent',
#   'whole',
#   'season',
#   'tri',
#   'rememb',
#   'skip',
#   'recap',
#   'didnt',
#   'want',
#   'googl',
#   'case',
#   'spoil'],
#  ['eras', 'head'],
#  ['didnt', 'say', 'smart', 'person'],
#  ['bet',
#   'someon',
#   'power',
#   'make',
#   'anyon',
#   'laugh',
#   'get',
#   'genuin',
#   'laugh',
#   'someon',
#   'one',
#   'thing',
#   'want',
#   'most',
#   'world'],
#  ['also',
#   'abl',
#   'make',
#   'someon',
#   'laugh',
#   'continu',
#   'easili',
#   'suffoc',
#   'keep',
#   'power'],
#  ['fair'],
#  ['littl', 'midoriya', 'most', 'ador', 'bbi', 'ever', 'seen'],
#  ['cute', 'die', 'now', 'ghost'],
#  ['super'],
#  ['delet'],
#  ['deku', 'mom', 'alway', 'great'],
#  ['best', 'mum'],
#  ['got'],
#  ['well'],
#  ['king', 'explos', 'murder', 'deku', 'mini', 'ador'],
#  ['delet'],
#  ['point',
#   'edit',
#   'dude',
#   'respond',
#   'said',
#   'even',
#   'though',
#   'mini',
#   'deku',
#   'cute',
#   'super',
#   'hero',
#   'name',
#   'chose',
#   'were',
#   'cringey'],
#  ['delet'],
#  ['pleas',
#   'get',
#   'flashback',
#   'quickli',
#   'dont',
#   'say',
#   'scene',
#   'mama',
#   'midoriya'],
#  ['dude', 'cring', 'much', 'littl', 'might', 'want', 'avoid', 'outsid'],
#  ['littl', 'child', 'embarras', 'about', 'love', 'idol', 'stop', 'project'],
#  ['not', 'smol', 'enough'],
#  ['gah', 'cute'],
#  ['bakugo', 'hero', 'name', 'were', 'fuck', 'priceless'],
#  ['think',
#   'some',
#   'name',
#   'like',
#   'inferno',
#   'blister',
#   'lord',
#   'explos',
#   'murder',
#   'total',
#   'caught',
#   'guard'],
#  ['not', 'differ', 'after', 'chuuni', 'through', 'through'],
#  ['expect', 'someth', 'like', 'boom', 'fuck', 'not', 'disappoint'],
#  ['manga', 'king', 'explodokil', 'glad', 'kept', 'similar', 'name', 'anim'],
#  ['bit',
#   'late',
#   'respons',
#   'obvious',
#   'pretti',
#   'sure',
#   'king',
#   'explos',
#   'murder',
#   'king',
#   'explodokil',
#   'more',
#   'less',
#   'liter',
#   'english',
#   'translat',
#   'same',
#   'thing'],
#  ['tri', 'put', 'name', 'crime', 'hero', 'name', 'bloodi', 'brilliant'],
#  ['remov'],
#  ['delet'],
#  ['idk',
#   'kinda',
#   'like',
#   'lord',
#   'explos',
#   'murder',
#   'better',
#   'imo',
#   'more',
#   'bakugo',
#   'baron',
#   'either',
#   'fine',
#   'bakugo',
#   'love',
#   'bakugo',
#   'life'],
#  ['baron',
#   'even',
#   'thing',
#   'japanes',
#   'danshaku',
#   'which',
#   'supposedli',
#   'equival',
#   'differ',
#   'origin',
#   'cant',
#   'find',
#   'enough',
#   'inform',
#   'confirm'],
#  ['yep',
#   'think',
#   'equival',
#   'after',
#   'quickish',
#   'googl',
#   'session',
#   'kinda',
#   'got',
#   'baron',
#   'basic',
#   'lowest',
#   'kind',
#   'british',
#   'nobil',
#   'right',
#   'japan',
#   'similar',
#   'system',
#   'base',
#   'british',
#   'well',
#   'call',
#   'kazoku',
#   'kazoku',
#   'system',
#   'divid',
#   'into',
#   'five',
#   'rank',
#   'duke',
#   'kshaku',
#   'marquess',
#   'kshaku',
#   'earl',
#   'hakushaku',
#   'viscount',
#   'shishaku',
#   'baron',
#   'danshaku',
#   'danshaku',
#   'lowest',
#   'five',
#   'mani',
#   'edit',
#   'later',
#   'cant',
#   'figur',
#   'italic',
#   'thing'],
#  ['impress',
#   'titl',
#   'baron',
#   'more',
#   'lowest',
#   'peerag',
#   'rank',
#   'imagin',
#   'baron',
#   'were',
#   'lord',
#   'own',
#   'castl',
#   'minor',
#   'tract',
#   'land',
#   'seem',
#   'least',
#   'franc',
#   'free',
#   'land',
#   'holder',
#   'were',
#   'automat',
#   'baron',
#   'feudal',
#   'landhold',
#   'were',
#   'entitl',
#   'style',
#   'themselv',
#   'baron',
#   'were',
#   'nobl',
#   'roturi',
#   'common',
#   'seigneur',
#   'baronni',
#   'lord',
#   'baroni',
#   'italic',
#   'add',
#   'asterik',
#   'befor',
#   'after',
#   'want',
#   'word'],
#  ['didnt', 'know', 'thank'],
#  ['talk', 'about', 'manga', 'fan', 'translat', 'which', 'know', 'accur'],
#  ['delet'],
#  ['arbitrari',
#   'assumpt',
#   'person',
#   'watch',
#   'anim',
#   'read',
#   'manga',
#   'regularli',
#   'realli',
#   'isnt',
#   'some',
#   'clear',
#   'cut',
#   'situat',
#   'often',
#   'translat',
#   'more',
#   'opinion',
#   'translat',
#   'adapt',
#   'differ',
#   'sentenc',
#   'languag',
#   'structur',
#   'english',
#   'other',
#   'languag',
#   'most',
#   'these',
#   'judgment',
#   'call',
#   'over',
#   'more',
#   'faith'],
#  ['thi',
#   'comment',
#   'remov',
#   'untag',
#   'improperli',
#   'tag',
#   'spoiler',
#   'not',
#   'allow',
#   'obvious',
#   'intent',
#   'excess',
#   'repeat',
#   'violat',
#   'rule',
#   'will',
#   'result',
#   'ban',
#   'self',
#   'link',
#   'post',
#   'should',
#   'properli',
#   'spoilertag',
#   'should',
#   'includ',
#   'name',
#   'show',
#   'referenc',
#   'titl',
#   'self',
#   'post',
#   'may',
#   'opt',
#   'tag',
#   'spoiler',
#   'self',
#   'post',
#   'instead',
#   'use',
#   'same',
#   'format',
#   'comment',
#   'spoiler',
#   'below',
#   'comment',
#   'should',
#   'use',
#   'spoiler',
#   'sourc',
#   'spoilerchan',
#   'die',
#   'protect',
#   'spoiler',
#   'spoiler',
#   'sourc',
#   'should',
#   'minimum',
#   'contain',
#   'relev',
#   'sourc',
#   'spoiler',
#   'one',
#   'piec',
#   'episod',
#   'differ',
#   'medium',
#   'manga',
#   'spoiler',
#   'sourc',
#   'requir',
#   'first',
#   'set',
#   'spoiler',
#   'same',
#   'sourc',
#   'not',
#   'requir',
#   'discuss',
#   'thread',
#   'while',
#   'discuss',
#   'thread',
#   'seri',
#   'question',
#   'think',
#   'remov',
#   'error',
#   'messag',
#   'mod',
#   'dont',
#   'know',
#   'rule',
#   'read',
#   'anim',
#   'wiki',
#   'rule'],
#  ['other',
#   'way',
#   'around',
#   'actual',
#   'start',
#   'king',
#   'explodokil',
#   'got',
#   'yell',
#   'turn',
#   'into',
#   'baron',
#   'explodo',
#   'kill'],
#  ['pretti', 'sure', 'pick', 'emperor', 'explodokil', 'end'],
#  ['might',
#   'choos',
#   'king',
#   'hero',
#   'name',
#   'becaus',
#   'want',
#   'hero',
#   'blast',
#   'base',
#   'quirk'],
#  ['will', 'crossov', 'episod', 'one', 'punch', 'man'],
#  ['decid', 'name', 'shall', 'blast', 'king'],
#  ['end', 'choos', 'kacchan', 'hero', 'name'],
#  ['definit', 'see', 'happen'],
#  ['there', 'need', 'way', 'more', 'charact', 'develop', 'take', 'name'],
#  ['manga', 'spoiler', 'intesifi'],
#  ['mean', 'manga'],
#  ['ehhhhhhhhhhh', 'not', 'way', 'more', 'see', 'happen'],
#  ['well', 'need', 'stop', 'complet', 'cunt', 'first'],
#  ['anoth', 'megumin', 'challeng'],
#  ['bakugo', 'best', 'girl'],
#  ['waga', 'bakug'],
#  ['want', 'name', 'megumin'],
#  ['megu', 'deku'],
#  ['name', 'bakago', 'call', 'lord', 'explos', 'murder'],
#  ['couldnt', 'choos', 'someth', 'like', 'explos', 'lord', 'hilari'],
#  ['murder', 'death', 'kill'],
#  ['some', 'swedish', 'weeb', 'dethgasm', 'right', 'now'],
#  ['get', 'face', 'paint'],
#  ['loud', 'laughter'],
#  ['cours', 'mic', 'aizawa', 'were', 'same', 'class'],
#  ['also', 'underclassman'],
#  ['remov'],
#  ['thi',
#   'comment',
#   'remov',
#   'untag',
#   'improperli',
#   'tag',
#   'spoiler',
#   'not',
#   'allow',
#   'obvious',
#   'intent',
#   'excess',
#   'repeat',
#   'violat',
#   'rule',
#   'will',
#   'result',
#   'ban',
#   'self',
#   'link',
#   'post',
#   'should',
#   'properli',
#   'spoilertag',
#   'should',
#   'includ',
#   'name',
#   'show',
#   'referenc',
#   'titl',
#   'self',
#   'post',
#   'may',
#   'opt',
#   'tag',
#   'spoiler',
#   'self',
#   'post',
#   'instead',
#   'use',
#   'same',
#   'format',
#   'comment',
#   'spoiler',
#   'below',
#   'comment',
#   'should',
#   'use',
#   'spoiler',
#   'sourc',
#   'spoilerchan',
#   'die',
#   'protect',
#   'spoiler',
#   'spoiler',
#   'sourc',
#   'should',
#   'minimum',
#   'contain',
#   'relev',
#   'sourc',
#   'spoiler',
#   'one',
#   'piec',
#   'episod',
#   'differ',
#   'medium',
#   'manga',
#   'spoiler',
#   'sourc',
#   'requir',
#   'first',
#   'set',
#   'spoiler',
#   'same',
#   'sourc',
#   'not',
#   'requir',
#   'discuss',
#   'thread',
#   'while',
#   'discuss',
#   'thread',
#   'seri',
#   'question',
#   'think',
#   'remov',
#   'error',
#   'messag',
#   'mod',
#   'dont',
#   'know',
#   'rule',
#   'read',
#   'anim',
#   'wiki',
#   'rule'],
#  ['need', 'tell', 'caught', 'both', 'manga'],
#  ['think',
#   'probabl',
#   'best',
#   'friend',
#   'even',
#   'though',
#   'aizawa',
#   'never',
#   'admit',
#   'especi',
#   'were',
#   'act',
#   'comment',
#   'togeth',
#   'feel',
#   'bromanc',
#   'between'],
#  ['despit',
#   'demeanor',
#   'aizawa',
#   'familiar',
#   'lot',
#   'crowdcontrol',
#   'type',
#   'hero',
#   'quit',
#   'year'],
#  ['last',
#   'episod',
#   'mic',
#   'made',
#   'silent',
#   'drink',
#   'gestur',
#   'aizawa',
#   'announcer',
#   'booth',
#   'aizawa',
#   'instantli',
#   'understood',
#   'take',
#   'friendship',
#   'least',
#   'lot',
#   'hang'],
#  ['better',
#   'way',
#   'avoid',
#   'attent',
#   'loudest',
#   'guy',
#   'room',
#   'steal',
#   'attent'],
#  ['yeah',
#   'total',
#   'see',
#   'guy',
#   'give',
#   'zero',
#   'fuck',
#   'guy',
#   'give',
#   'zero',
#   'fuck',
#   'about',
#   'other',
#   'guy',
#   'give',
#   'zero',
#   'fuck',
#   'know',
#   'becaus',
#   'former',
#   'friendship'],
#  ['gai', 'kakashi', 'over', 'again'],
#  ['springtim', 'youth'],
#  ['gran',
#   'torino',
#   'sound',
#   'super',
#   'familiar',
#   'not',
#   'dude',
#   'old',
#   'man',
#   'white',
#   'hair',
#   'holi',
#   'shit',
#   'horikoshi',
#   'name',
#   'after',
#   'clint',
#   'eastwood',
#   'gran',
#   'torino'],
#  ['wrong',
#   'didnt',
#   'watch',
#   'star',
#   'war',
#   'read',
#   'gran',
#   'torino',
#   'thought',
#   'gran',
#   'tesoro',
#   'one',
#   'piec',
#   'gold'],
#  ['think',
#   'gran',
#   'turismo',
#   'didnt',
#   'know',
#   'gran',
#   'torino',
#   'nice',
#   'catch'],
#  ['horikoshi',
#   'said',
#   'inspir',
#   'yoda',
#   'big',
#   'star',
#   'war',
#   'fan',
#   'lot',
#   'star',
#   'war',
#   'easter',
#   'egg',
#   'boku',
#   'hero'],
#  ['further', 'seri', 'there', 'boondock', 'saint', 'refer', 'most', 'like'],
#  ['see',
#   'get',
#   'lot',
#   'differ',
#   'respons',
#   'right',
#   'horikoshi',
#   'absolut',
#   'master',
#   'multifacet',
#   'name'],
#  ['also', 'author', 'base', 'charact', 'yoda', 'star', 'war'],
#  ['think', 'master', 'korin', 'yoda', 'work'],
#  ['also',
#   'refer',
#   'car',
#   'which',
#   'also',
#   'appear',
#   'movi',
#   'ford',
#   'gran',
#   'torino',
#   'use',
#   'realli',
#   'famou',
#   'car',
#   'usa',
#   'boku',
#   'hero',
#   'fill',
#   'american',
#   'refer',
#   'also',
#   'boku',
#   'hero',
#   'minor',
#   'spoiler',
#   'gran',
#   'torino',
#   'quirk',
#   'someth',
#   'speed'],
#  ['spoiler', 'preview'],
#  ['dunno',
#   'sinc',
#   'got',
#   'some',
#   'messag',
#   'remov',
#   'thing',
#   'thought',
#   'spoiler',
#   'put',
#   'everyth',
#   'sure'],
#  ['which', 'make', 'sens', 'consid', 'fast', 'shown'],
#  ['boku',
#   'hero',
#   'gran',
#   'torino',
#   'also',
#   'success',
#   'race',
#   'heritag',
#   'nascar',
#   'not',
#   'fan',
#   'race',
#   'know',
#   'gran',
#   'torino',
#   'known',
#   'run',
#   'tabl',
#   'late',
#   'into',
#   'earli',
#   'ford',
#   'sound',
#   'like',
#   'perfect',
#   'superhero',
#   'name',
#   'old',
#   'timer'],
#  ['comparis',
#   'thought',
#   'mere',
#   'coincid',
#   'gran',
#   'torino',
#   'same',
#   'name',
#   'movi',
#   'same',
#   'look',
#   'nice',
#   'cath',
#   'btw',
#   'get',
#   'time',
#   'watch',
#   'movi',
#   'pretti',
#   'dope',
#   'extra',
#   'also',
#   'movi',
#   'old',
#   'man',
#   'teach',
#   'asian',
#   'kid',
#   'life',
#   'grow',
#   'grand',
#   'torino',
#   'teach',
#   'asian',
#   'kid',
#   'hero',
#   'there',
#   'much',
#   'comparison',
#   'lel'],
#  ['watch',
#   'movi',
#   'not',
#   'long',
#   'ago',
#   'after',
#   'hear',
#   'about',
#   'good',
#   'sinc',
#   'rememb',
#   'truli',
#   'fuck',
#   'suck',
#   'clint',
#   'eastwood',
#   'act',
#   'best',
#   'thing',
#   'about',
#   'even',
#   'shit',
#   'becaus',
#   'cring',
#   'fuck',
#   'write',
#   'cring',
#   'start',
#   'finish',
#   'promptli',
#   'turn',
#   'shit',
#   'dure',
#   'scene',
#   'clint',
#   'attitud',
#   'toward',
#   'minor',
#   'flick',
#   'like',
#   'switch',
#   'basement',
#   'asian',
#   'parti',
#   'hang',
#   'teenag',
#   'give',
#   'kid',
#   'embodi',
#   'everi',
#   'stupid',
#   'fuck',
#   'teenag',
#   'trope',
#   'there',
#   'talk',
#   'about',
#   'girl',
#   'fuck',
#   'gran',
#   'torino',
#   'fuck',
#   'everyon',
#   'led',
#   'think',
#   'wouldnt',
#   'wast',
#   'time',
#   'watch'],
#  ['enjoy',
#   'watch',
#   'backward',
#   'see',
#   'about',
#   'old',
#   'guy',
#   'friendli',
#   'asian',
#   'littl',
#   'littl',
#   'get',
#   'heart',
#   'harder',
#   'harder',
#   'final',
#   'becom',
#   'sour',
#   'hermit',
#   'hate',
#   'minor'],
#  ['liter', 'saw', 'most', 'movi', 'last', 'weekend'],
#  ['also',
#   'alien',
#   'queen',
#   'obvious',
#   'refer',
#   'alien',
#   'manga',
#   'directli',
#   'mention',
#   'ridley',
#   'scott'],
#  ['liter', 'depict', 'ridley', 'scott', 'alien', 'thank', 'point'],
#  ['welcom', 'there', 'need', 'thank'],
#  ['delet'],
#  ['see',
#   'next',
#   'episod',
#   'preview',
#   'first',
#   'thought',
#   'yoda',
#   'funni',
#   'becaus',
#   'didnt',
#   'think',
#   'star',
#   'war',
#   'popular',
#   'japan'],
#  ['one', 'first', 'scene', 'anim', 'manga', 'star', 'war', 'refrenc'],
#  ['case',
#   'havent',
#   'notic',
#   'horikoshi',
#   'love',
#   'drop',
#   'star',
#   'war',
#   'refer',
#   'everi',
#   'opportun',
#   'get',
#   'beach',
#   'deku',
#   'train',
#   'call',
#   'dagobah',
#   'metro',
#   'station',
#   'call',
#   'tatooin',
#   'hosu',
#   'citi',
#   'pretti',
#   'much',
#   'hoth',
#   'assum',
#   'there',
#   'even',
#   'more',
#   'manga',
#   'animeonli',
#   'scrub'],
#  ['there',
#   'more',
#   'later',
#   'kamino',
#   'kashyyyk',
#   'mustafar',
#   'etc',
#   'top',
#   'head',
#   'anoth',
#   'one',
#   'alreadi',
#   'mention',
#   'anim',
#   'deku',
#   'bakugo',
#   'were',
#   'origin',
#   'alderaa',
#   'middl',
#   'school',
#   'shinsou',
#   'naboo',
#   'nabu',
#   'probabl',
#   'alreadi',
#   'cover',
#   'instead',
#   'write',
#   'katakana',
#   'horikoshi',
#   'use',
#   'kanji',
#   'read',
#   'way',
#   'tatooin',
#   'tatouin',
#   'alderaan',
#   'oridera',
#   'hoth',
#   'hosu'],
#  ['later',
#   'manga',
#   'there',
#   'more',
#   'variou',
#   'movi',
#   'refer',
#   'think',
#   'author',
#   'pretti',
#   'dope'],
#  ['lotta', 'star', 'war'],
#  ['probabl', 'aspect', 'both'],
#  ['also',
#   'anoth',
#   'star',
#   'war',
#   'refer',
#   'short',
#   'dude',
#   'cane',
#   'teacher',
#   'teacher',
#   'guess',
#   'hori',
#   'design',
#   'after',
#   'yoda'],
#  ['there', 'tatooin', 'station', 'begin', 'episod', 'well'],
#  ['even',
#   'beach',
#   'park',
#   'season',
#   'one',
#   'star',
#   'war',
#   'refer',
#   'pretti',
#   'sure',
#   'call',
#   'dagobah',
#   'beach',
#   'park',
#   'there',
#   'also',
#   'tatooin',
#   'later',
#   'seri',
#   'rememb',
#   'correctli'],
#  ['one', 'next', 'arc', 'manga', 'take', 'place', 'kamino', 'ward'],
#  ['there', 'also', 'kashyyyk', 'wooki', 'some', 'point'],
#  ['ingenium', 'got', 'attack', 'hosu', 'which', 'probabl', 'refer', 'hoth'],
#  ['hosu', 'real', 'place', 'locat', 'ishikawa', 'perfectur'],
#  ['thought', 'might', 'case'],
#  ['yeah',
#   'subtl',
#   'lot',
#   'harder',
#   'catch',
#   'tatooin',
#   'dagobah',
#   'never',
#   'actual',
#   'thought',
#   'about'],
#  ['tatooin', 'actual', 'area', 'first', 'see', 'seri', 'ladi', 'made', 'debut'],
#  ['never', 'notic', 'one', 'damn', 'think', 'first', 'mention', 'tatooin'],
#  ['episod', 'fact'],
#  ['yeah', 'wonder', 'typo', 'translat'],
#  ['feel', 'like', 'charact', 'show', 'close', 'peopl', 'know', 'care', 'about'],
#  ['wait',
#   'til',
#   'start',
#   'feel',
#   'way',
#   'about',
#   'class',
#   'joy',
#   'never',
#   'stop'],
#  ['charact', 'yeah', 'man', 'noumu', 'like', 'total', 'bro'],
#  ['remov'],
#  ['thi',
#   'comment',
#   'remov',
#   'untag',
#   'improperli',
#   'tag',
#   'spoiler',
#   'not',
#   'allow',
#   'obvious',
#   'intent',
#   'excess',
#   'repeat',
#   'violat',
#   'rule',
#   'will',
#   'result',
#   'ban',
#   'self',
#   'link',
#   'post',
#   'should',
#   'properli',
#   'spoilertag',
#   'should',
#   'includ',
#   'name',
#   'show',
#   'referenc',
#   'titl',
#   'self',
#   'post',
#   'may',
#   'opt',
#   'tag',
#   'spoiler',
#   'self',
#   'post',
#   'instead',
#   'use',
#   'same',
#   'format',
#   'comment',
#   'spoiler',
#   'below',
#   'comment',
#   'should',
#   'use',
#   'spoiler',
#   'sourc',
#   'spoilerchan',
#   'die',
#   'protect',
#   'spoiler',
#   'spoiler',
#   'sourc',
#   'should',
#   'minimum',
#   'contain',
#   'relev',
#   'sourc',
#   'spoiler',
#   'one',
#   'piec',
#   'episod',
#   'differ',
#   'medium',
#   'manga',
#   'spoiler',
#   'sourc',
#   'requir',
#   'first',
#   'set',
#   'spoiler',
#   'same',
#   'sourc',
#   'not',
#   'requir',
#   'discuss',
#   'thread',
#   'while',
#   'discuss',
#   'thread',
#   'seri',
#   'question',
#   'think',
#   'remov',
#   'error',
#   'messag',
#   'mod',
#   'dont',
#   'know',
#   'rule',
#   'read',
#   'anim',
#   'wiki',
#   'rule'],
#  ['spoiler'],
#  ['cant',
#   'judg',
#   'becaus',
#   'one',
#   'time',
#   'mayb',
#   'chill',
#   'guy',
#   'bad',
#   'day'],
#  [],
#  ['like', 'spoiler'],
#  ['usual',
#   'someon',
#   'els',
#   'answer',
#   'stuff',
#   'previou',
#   'episod',
#   'dont',
#   'think',
#   'spoiler',
#   'need',
#   'situat'],
#  ['noumu',
#   'villain',
#   'creatur',
#   'strong',
#   'enough',
#   'take',
#   'might',
#   'season',
#   'kid',
#   'were',
#   'attack',
#   'larg',
#   'group',
#   'villain'],
#  ['right', 'forgot', 'thing', 'name'],
#  ['man',
#   'might',
#   'great',
#   'iida',
#   'journey',
#   'fall',
#   'dark',
#   'side',
#   'dont',
#   'walk',
#   'down',
#   'path',
#   'roy',
#   'mustang'],
#  ['doesnt', 'hawkey', 'watch', 'back', 'hugh', 'aliv', 'well'],
#  ['speak', 'roy', 'mustang', 'might', 'same', 'person', 'scar'],
#  ['scene',
#   'bit',
#   'forgett',
#   'manga',
#   'voic',
#   'act',
#   'anim',
#   'foley',
#   'work',
#   'ofc',
#   'made',
#   'fuck',
#   'hilari'],
#  ['want',
#   'give',
#   'shout',
#   'chri',
#   'sabat',
#   'great',
#   'job',
#   'scene',
#   'well',
#   'manga',
#   'version',
#   'anyone',
#   'interest'],
#  ['like', 'manga', 'imag', 'link', 'realli', 'need', 'count'],
#  ['pretti',
#   'dope',
#   'usual',
#   'hate',
#   'dub',
#   'sound',
#   'amaz',
#   'deku',
#   'sound',
#   'littl',
#   'weird',
#   'wasnt',
#   'much'],
#  ['hate',
#   'dub',
#   'like',
#   'becaus',
#   'use',
#   'shitti',
#   'one',
#   'get',
#   'done',
#   'dont',
#   'pay',
#   'respect',
#   'sourc',
#   'materi',
#   'mha',
#   'dub',
#   'noth',
#   'like',
#   'though',
#   'tri',
#   'keep',
#   'everyth',
#   'close',
#   'without',
#   'chang',
#   'word',
#   'much',
#   'chang',
#   'word',
#   'keep',
#   'origin',
#   'mean',
#   'tact',
#   'least',
#   'reason',
#   'might',
#   'sound',
#   'weird',
#   'becaus',
#   'arent',
#   'use',
#   'voic',
#   'yet',
#   'actual',
#   'realli',
#   'like',
#   'deku',
#   'english',
#   'voic',
#   'sound',
#   'like',
#   'perfect',
#   'mix',
#   'timidbutdetermin',
#   'defin',
#   'charact',
#   'well',
#   'ever',
#   'mood',
#   'rewatch',
#   'seri',
#   'definit',
#   'recommend',
#   'check',
#   'dub',
#   'theyr',
#   'amaz',
#   'job',
#   'like',
#   'make',
#   'sure',
#   'peopl',
#   'see',
#   'kind',
#   'qualiti',
#   'effort',
#   'goe',
#   'into',
#   'dub',
#   'normal',
#   'dont',
#   'see',
#   'anoth',
#   'good',
#   'one',
#   'dub',
#   'might',
#   'battl',
#   'against',
#   'nomu',
#   'chri',
#   'sabat',
#   'absolut',
#   'nail',
#   'well',
#   'realli',
#   'like',
#   'might'],
#  ['yeah',
#   'pretti',
#   'awesom',
#   'hard',
#   'even',
#   'bother',
#   'dub',
#   'becaus',
#   'easi',
#   'miss',
#   'seen',
#   'cowboy',
#   'bebop',
#   'samurai',
#   'champloo',
#   'dub',
#   'both',
#   'were',
#   'perfect',
#   'sinc',
#   'much',
#   'anim',
#   'about',
#   'teenag',
#   'voic',
#   'act',
#   'seem',
#   'weird',
#   'becaus',
#   'some',
#   'anim',
#   'year',
#   'old',
#   'sound',
#   'like',
#   'theyr'],
#  ['gener',
#   'start',
#   'new',
#   'show',
#   'there',
#   'dub',
#   'avail',
#   'ill',
#   'watch',
#   'both',
#   'dub',
#   'sub',
#   'first',
#   'coupl',
#   'episod',
#   'decid',
#   'which',
#   'one',
#   'ill',
#   'continu',
#   'watch',
#   'dub',
#   'garbag',
#   'pretti',
#   'easi',
#   'tell',
#   'within',
#   'coupl',
#   'episod',
#   'definit',
#   'nicer',
#   'abl',
#   'watch',
#   'without',
#   'eye',
#   'glu',
#   'bottom',
#   'screen',
#   'sinc',
#   'often',
#   'watch',
#   'anim',
#   'while',
#   'other',
#   'thing',
#   'far',
#   'mha',
#   'one',
#   'actual',
#   'gone',
#   'back',
#   'watch',
#   'both',
#   'version',
#   'becaus',
#   'much',
#   'enjoy'],
#  ['love', 'fmab'],
#  ['enjoy',
#   'fma',
#   'not',
#   'much',
#   'mha',
#   'watch',
#   'fma',
#   'dub',
#   'mayb',
#   'ill',
#   'watch',
#   'sub',
#   'ever',
#   'mood',
#   'rewatch',
#   'though',
#   'gotta',
#   'get',
#   'through',
#   'backlog',
#   'first'],
#  ['nice', 'think', 'didnt', 'watch', 'dub', 'mention', 'way'],
#  ['yeah',
#   'said',
#   'gener',
#   'dub',
#   'first',
#   'unless',
#   'tell',
#   'shitti',
#   'dub',
#   'dub',
#   'doesnt',
#   'exist',
#   'like',
#   'watch',
#   'one',
#   'punch',
#   'man',
#   'befor',
#   'dub',
#   'came',
#   'still',
#   'havent',
#   'seen',
#   'dub',
#   'good',
#   'not'],
#  ['sub',
#   'viewer',
#   'not',
#   'realiz',
#   'chri',
#   'sabat',
#   'voic',
#   'might',
#   'make',
#   'sens',
#   'though',
#   'zoro',
#   'voic',
#   'manliest',
#   'charact'],
#  ['vegeta'],
#  ['piccolo'],
#  ['major', 'alex', 'loui', 'armstrong'],
#  ['yeah',
#   'get',
#   'alex',
#   'loui',
#   'armstrong',
#   'strongarm',
#   'alchemist',
#   'perform',
#   'might'],
#  ['care', 'weeb', 'might', 'attack'],
#  ['onli', 'complaint', 'far', 'good', 'season'],
#  ['speak', 'mate', 'thought', 'line', 'use', 'instead', 'amaz'],
#  ['nah', 'dub', 'consist', 'fantast'],
#  ['agre',
#   'sometim',
#   'see',
#   'weeaboo',
#   'pop',
#   'into',
#   'thread',
#   'say',
#   'voic',
#   'unfamiliar',
#   'not',
#   'way',
#   'should',
#   'sound',
#   'seen',
#   'disturb',
#   'amount',
#   'peopl',
#   'genuin',
#   'surpris',
#   'modern',
#   'day',
#   'dub',
#   'good',
#   'not',
#   'great'],
#  ['haha',
#   'worri',
#   'bnha',
#   'well',
#   'regard',
#   'one',
#   'best',
#   'dub',
#   'there',
#   'theyr',
#   'put',
#   'ton',
#   'effort',
#   'into',
#   'realli',
#   'show'],
#  ['put', 'same', 'effort', 'into', 'attack', 'titan'],
#  ['eeeeeeeeeeeeeerrrrrrrrrrrrrrriiiiiiiiiiiiiinnnnnnnnnnn'],
#  [],
#  [],
#  ['king', 'explos', 'murder', 'megub'],
#  ['megumin', 'fan'],
#  ['perhap', 'other', 'way', 'around'],
#  ['thi', 'loli', 'fuck', 'cute', 'holi', 'fuck', 'shit', 'see', 'now'],
#  ['lord', 'explos', 'murder'],
#  ['one', 'hell', 'compliment'],
#  ['like', 'superhero', 'name', 'pussydestroyerxxx', 'thehardon'],
#  ['deku',
#   'might',
#   'midnight',
#   'might',
#   'alreadi',
#   'taken',
#   'though',
#   'deku',
#   'deku',
#   'might',
#   'midnight'],
#  ['one', 'said', 'box', 'one'],
#  ['hey', 'superhero', 'name', 'not', 'xbox', 'live'],
#  [],
#  ['about', 'ililliliilil'],
#  ['ljsbsldciwnpxwyetvixiwiz', 'better'],
#  ['hope', 'yasqueenslay', 'still', 'grab'],
#  ['krusher'],
#  ['will', 'rate', 'hero'],
#  ['legend', 'wasnt', 'taken'],
#  ['xxx', 'noscopeblazeit', 'kunxxx'],
#  ['promis',
#   'much',
#   'ever',
#   'get',
#   'superpow',
#   'even',
#   'remot',
#   'realm',
#   'shoot',
#   'ill',
#   'call',
#   'scope'],
#  ['xxxifukedurm', 'mxxx'],
#  ['usernam', 'unavail'],
#  ['xxx', 'noscopeblazeit', 'kunxxx', 'boom', 'fix'],
#  ['these', 'symbol', 'alik', 'not', 'allow'],
#  ['refus', 'entir', 'chang', 'usernam', 'xxx', 'noscopeblazeitkunxxx'],
#  ['password', 'must', 'contain', 'capit', 'letter'],
#  ['though', 'capit', 'capit'],
#  ['uhhh', 'hmmmm', 'xxx', 'noscopeblazeitkunxxx'],
#  ['usernam', 'alreadi', 'taken'],
#  ['wait',
#   'switch',
#   'usernam',
#   'password',
#   'continu',
#   'use',
#   'usernam',
#   'password',
#   'well',
#   'welp',
#   'xxxnoscopeblazeitkunxxx'],
#  ['fuck', 'bad', 'destroy', 'whole', 'thing', 'lol'],
#  ['shall', 'now', 'known', 'wholethingdestroyerxxx'],
#  ['ballsdeep', 'alreadi', 'taken'],
#  ['sigh', 'thank', 'remind', 'sad', 'stop', 'make', 'episod'],
#  ['plan', 'rest', 'sao', 'theyr', 'still', 'work', 'season'],
#  ['cours',
#   'there',
#   'one',
#   'man',
#   'worthi',
#   'titl',
#   'legendari',
#   'fuck',
#   'great',
#   'klein'],
#  ['thelegend'],
#  ['pfft', 'shut', 'eyliel', 'come', 'back', 'main', 'charact'],
#  ['rip', 'eyliel', 'screen', 'time'],
#  ['xxballsdeep', 'still', 'free'],
#  ['see', 'want', 'pay', 'homag', 'great', 'hero', 'ballsdeep'],
#  ['scene', 'melt', 'anyon', 'els', 'ici', 'heart'],
#  ['also', 'mom', 'sweet', 'there'],
#  ['like',
#   'well',
#   'final',
#   'episod',
#   'boku',
#   'hero',
#   'wont',
#   'cri',
#   'scene',
#   'happen'],
#  ['hahaha',
#   'yeah',
#   'understand',
#   'almost',
#   'tear',
#   'kirishima',
#   'hero',
#   'name',
#   'dude',
#   'manli',
#   'earnest'],
#  ['man',
#   'kirishima',
#   'sincer',
#   'becom',
#   'hero',
#   'pretti',
#   'great',
#   'love',
#   'get',
#   'hear',
#   'other',
#   'hero',
#   'look',
#   'inspir'],
#  ['want',
#   'entir',
#   'show',
#   'babi',
#   'deku',
#   'dekumom',
#   'serious',
#   'best',
#   'mom',
#   'boy'],
#  ['bakugo',
#   'hand',
#   'there',
#   'thisd',
#   'make',
#   'good',
#   'doujin',
#   'wait',
#   'theyr',
#   'kid',
#   'fuck',
#   'forget',
#   'said',
#   'anyth'],
#  ['there', 'werent', 'manga', 'featur'],
#  ['pictur', 'miss', 'kettl', 'some', 'scald', 'hot', 'water'],
#  ['todoroki', 'mom', 'though'],
#  [],
#  ['piec', 'shit', 'burn', 'son'],
#  ['not', 'fault'],
#  ['not', 'get', 'kettl', 'throw', 'todoroki'],
#  ['not',
#   'get',
#   'abus',
#   'father',
#   'child',
#   'point',
#   'see',
#   'kid',
#   'half',
#   'face',
#   'relanc',
#   'which',
#   'similar',
#   'abus',
#   'throw',
#   'bole',
#   'water',
#   'first',
#   'reaction',
#   'protect',
#   'youself',
#   'more',
#   'potenti',
#   'abus',
#   'not',
#   'enough',
#   'reason',
#   'feel',
#   'empathi',
#   'not',
#   'blame',
#   'instead',
#   'father'],
#  ['not',
#   'mom',
#   'there',
#   'way',
#   'mistook',
#   'year',
#   'old',
#   'son',
#   'tower',
#   'behemoth',
#   'husband',
#   'also',
#   'ever',
#   'throw',
#   'boil',
#   'water',
#   'one',
#   'actual',
#   'abus'],
#  ['got', 'sent', 'hospit', 'todoroki', 'shed', 'morgu', 'endeavor'],
#  ['fair', 'doesnt', 'anyth', 'first', 'point', 'though'],
#  ['boy',
#   'mom',
#   'realli',
#   'got',
#   'deku',
#   'shoto',
#   'backstori',
#   'realli',
#   'hope',
#   'relationship',
#   'mom',
#   'improv',
#   'usual',
#   'anim',
#   'mom',
#   'parent',
#   'realli',
#   'arent',
#   'best',
#   'nice',
#   'see',
#   'some',
#   'good',
#   'famili',
#   'relationship'],
#  ['veri', 'cute', 'give', 'sauc', 'pic'],
#  ['realli',
#   'want',
#   'mum',
#   'friend',
#   'thatd',
#   'realli',
#   'nice',
#   'also',
#   'upscal',
#   'imag',
#   'wallpap',
#   'use',
#   'realli',
#   'nice',
#   'look',
#   'piec',
#   'artwork'],
#  ['dont',
#   'know',
#   'includ',
#   'mama',
#   'todoroki',
#   'list',
#   'best',
#   'ador',
#   'pictur'],
#  ['dont',
#   'rememb',
#   'theyv',
#   'ever',
#   'shown',
#   'bakugo',
#   'mom',
#   'yet',
#   'anim',
#   'lol',
#   'bakugo',
#   'boob',
#   'grab',
#   'todoroki',
#   'mom',
#   'fine',
#   'best',
#   'mom',
#   'still',
#   'best',
#   'mom'],
#  ['fuck', 'boil', 'mom', 'best', 'mom'],
#  ['best',
#   'mom',
#   'until',
#   'abus',
#   'husband',
#   'gave',
#   'posttraumat',
#   'stress',
#   'disord'],
#  ['whi', 'littl', 'bakug', 'grab', 'nevermind'],
#  ['now', 'want', 'becom', 'littl', 'bakug', 'ero'],
#  ['moment', 'bakugou', 'quirk', 'develop'],
#  ['tri', 'push', 'hug'],
#  ['bakugo',
#   'bit',
#   'bulli',
#   'asshol',
#   'deku',
#   'becom',
#   'depress',
#   'learn',
#   'doesnt',
#   'natur',
#   'quirk',
#   'todoroki',
#   'becom',
#   'slightli',
#   'unhing',
#   'due',
#   'father',
#   'abus',
#   'get',
#   'boil',
#   'water',
#   'pour',
#   'face',
#   'lose',
#   'mother',
#   'psychiatr',
#   'facil'],
#  ['pretend',
#   'altern',
#   'univers',
#   'bakugo',
#   'grumpi',
#   'littl',
#   'boy',
#   'instead',
#   'full',
#   'blown',
#   'asshol',
#   'deku',
#   'might',
#   'illegitim',
#   'child',
#   'got',
#   'toneddown',
#   'version',
#   'ofa',
#   'somehow',
#   'todoroki',
#   'dad',
#   'die',
#   'befor',
#   'whole',
#   'abus',
#   'boil',
#   'water',
#   'incid',
#   'say',
#   'stain',
#   'got',
#   'while',
#   'still',
#   'inexperienc'],
#  ['cours', 'littl', 'spice', 'sugar'],
#  ['gonna', 'boil', 'eye', 'real', 'quick'],
#  ['sol', 'call', 'littl', 'hero'],
#  ['littl', 'hero', 'academia'],
#  ['academia', 'babi', 'allmight', 'nanni', 'sock'],
#  ['ehh', 'life', 'home', 'not', 'life', 'academi'],
#  ['littl', 'hero', 'kindergarten'],
#  ['while',
#   'king',
#   'explos',
#   'murder',
#   'fine',
#   'name',
#   'think',
#   'bakug',
#   'deserv',
#   'better',
#   'name',
#   'someth',
#   'stylish',
#   'yet',
#   'explodei',
#   'someth',
#   'legendari',
#   'someth',
#   'like',
#   'know',
#   'chunchunmaru'],
#  ['someon',
#   'youtub',
#   'comment',
#   'said',
#   'perfect',
#   'hero',
#   'name',
#   'short',
#   'fuse',
#   'wholeheartedli',
#   'agre'],
#  ['whi', 'not', 'burn', 'fight', 'fighter'],
#  ['chunchunmaru', 'someon', 'explain', 'dont', 'get'],
#  ['will',
#   'shed',
#   'tear',
#   'unenlighten',
#   'soul',
#   'not',
#   'grace',
#   'view',
#   'konosuba'],
#  ['watch', 'konosuba', 'will', 'not', 'regret'],
#  ['lol', 'complet', 'unexpect'],
#  ['nah', 'gonna', 'blast', 'found', 'bnha', 'share', 'same', 'univers', 'opm'],
#  ['big', 'mara', 'ippo'],
#  ['about', 'sparki', 'sparki', 'boom', 'man'],
#  ['guy', 'not', 'amus'],
#  [],
#  ['konosubawot'],
#  ['famou', 'partner', 'guy'],
#  ['origin', 'translat', 'baron', 'explodokil'],
#  ['wow', 'laughter'],
#  ['strang', 'sure', 'viz', 'use', 'lord', 'explos', 'murder'],
#  ['meant', 'scanlat'],
#  ['know', 'like', 'pretend', 'dont', 'exist'],
#  ['yet', 'gave', 'more', 'interest', 'translat', 'make', 'think'],
#  ['feel', 'viz', 'translat', 'more', 'charact'],
#  ['ochinchin'],
#  ['midnight', 'wouldv', 'probabl', 'love', 'nicoisdon'],
#  ['damn', 'everi', 'time', 'see', 'refer', 'hear', 'song', 'head'],
#  ['filthi', 'frank'],
#  ['dont', 'think', 'someth', 'frank', 'might', 'wrong', 'though'],
#  ['one', 'speak', 'hilari', 'japanes', 'end', 'filthi', 'frank', 'meant'],
#  ['ohhhh', 'gotcha'],
#  ['lolicon', 'bless'],
#  ['exist',
#   'mean',
#   'amaz',
#   'cancer',
#   'same',
#   'time',
#   'kind',
#   'way',
#   'also',
#   'not',
#   'megumin',
#   'mayb',
#   'littl',
#   'megumin'],
#  ['dont', 'know', 'look', 'around', 'late', 'anim', 'commun', 'littl', 'weird'],
#  ['nonsens', 'not', 'weird'],
#  ['usernam', 'usernam', 'not', 'check'],
#  ['notmymegumin'],
#  ['nah', 'got', 'dynamight'],
#  ['mayb', 'hiroshima', 'nagasaki', 'hide'],
#  ['victorbomb'],
#  ['shit', 'actual', 'pretti', 'good'],
#  ['more', 'partial', 'bright'],
#  ['haha', 'like', 'one'],
#  ['brite', 'need', 'new', 'costum'],
#  ['color', 'want', 'paint', 'world', 'blood', 'red'],
#  ['should', 'name', 'crimson', 'demon', 'honour', 'megumin', 'meguminthumbsup'],
#  ['actual',
#   'friggin',
#   'heresi',
#   'megumin',
#   'pov',
#   'bakug',
#   'use',
#   'deton',
#   'magic',
#   'instead',
#   'explos',
#   'magic'],
#  ['still', 'boom', 'end'],
#  ['nope', 'sparki', 'sparki', 'boom', 'man'],
#  ['think', 'ive', 'heard', 'chitogheh'],
#  ['sokka', 'gloriou', 'bastard'],
#  ['best', 'best'],
#  ['sokka', 'boomerang', 'firebend', 'mind', 'phrase', 'weird'],
#  ['gah', 'cursor', 'omg', 'remov', 'cursor', 'freak'],
#  ['poor', 'soul', 'whomst', 'never', 'seen', 'avatar'],
#  ['wtf',
#   'never',
#   'saw',
#   'avatar',
#   'way',
#   'through',
#   'aang',
#   'hair',
#   'weird',
#   'look'],
#  ['yeah',
#   'end',
#   'think',
#   'goe',
#   'into',
#   'coma',
#   'while',
#   'wake',
#   'hair',
#   'seen',
#   'zuko',
#   'hair'],
#  ['fire', 'bender', 'right', 'pretti', 'sure'],
#  ['yeah'],
#  ['one', 'favorit', 'anim'],
#  ['not', 'anim', 'though'],
#  ['mod', 'get', 'hahaha'],
#  ['quick', 'hide', 'iceberg', 'mod', 'cant', 'find', 'year'],
#  ['everyth', 'chang', 'mod', 'nation', 'attack'],
#  ['hero',
#   'name',
#   'hype',
#   'dekuhyp',
#   'froppi',
#   'pinki',
#   'deku',
#   'lord',
#   'explos',
#   'murder',
#   'yousaidsomethingdumb',
#   'thing',
#   'move',
#   'along',
#   'now',
#   'internship',
#   'train',
#   'look',
#   'like',
#   'gonna',
#   'great',
#   'arc',
#   'old',
#   'man',
#   'look',
#   'kooki',
#   'fun',
#   'deku',
#   'kid',
#   'think',
#   'hero',
#   'name',
#   'best',
#   'best',
#   'mom',
#   'babe',
#   'after',
#   'credit',
#   'get',
#   'peek',
#   'deku',
#   'new',
#   'costum',
#   'awwwww',
#   'man',
#   'cant',
#   'wait'],
#  ['deku', 'kid', 'think', 'hero', 'name'],
#  ['hand',
#   'not',
#   'best',
#   'type',
#   'spell',
#   'check',
#   'everi',
#   'time',
#   'write',
#   'someth',
#   'nerv',
#   'damag',
#   'both',
#   'hand',
#   'dont',
#   'type',
#   'want',
#   'most',
#   'time',
#   'miss',
#   'one',
#   'lol'],
#  ['sentenc'],
#  ['wonder', 'red', 'mean', 'guess', 'show', 'not', 'colour', 'part', 'charact'],
#  ['denot',
#   'background',
#   'sinc',
#   'way',
#   'scene',
#   'usual',
#   'made',
#   'charact',
#   'drawn',
#   'essenti',
#   'place',
#   'top',
#   'background',
#   'composit',
#   'softwar'],
#  [],
#  ['colour', 'version'],
#  ['want', 'protect', 'smile'],
#  ['late'],
#  ['damn'],
#  ['delet', 'thi'],
#  ['delet', 'thi', 'nephew'],
#  ['delet', 'thi', 'ftfi'],
#  ['ftfi'],
#  ['jesu', 'wasnt', 'expect', 'laugh', 'hard', 'today'],
#  ['wallpunch', 'werent', 'strong', 'enough'],
#  ['done'],
#  ['thi', 'should', 'definit', 'comment', 'face'],
#  ['damn', 'paint'],
#  ['sorri'],
#  ['yamero'],
#  ['bottom',
#   'right',
#   'corner',
#   'think',
#   'forgot',
#   'colour',
#   'rest',
#   'white',
#   'sheet',
#   'due',
#   'deep',
#   'camera',
#   'pan',
#   'now',
#   'see',
#   'cant',
#   'feel',
#   'leg'],
#  ['qualityanim'],
#  ['wonder', 'couldnt', 'feel', 'leg'],
#  ['liter', 'unwatch'],
#  ['stare',
#   'bottom',
#   'left',
#   'corner',
#   'wonder',
#   'exactli',
#   'wrong',
#   'long',
#   'time',
#   'mean',
#   'bottom',
#   'right',
#   'right'],
#  ['save', 'hour', 'confus'],
#  ['stare', 'bottom', 'left', 'after', 'edit'],
#  ['yep',
#   'haha',
#   'dont',
#   'know',
#   'got',
#   'confus',
#   'over',
#   'left',
#   'right',
#   'again',
#   'still',
#   'earli'],
#  ['didnt',
#   'wanna',
#   'say',
#   'anyth',
#   'earlier',
#   'cant',
#   'feel',
#   'leg',
#   'anymor',
#   'well',
#   'didnt',
#   'wanna',
#   'say',
#   'anyth',
#   'earlier',
#   'dont',
#   'leg',
#   'anymor',
#   'onichan'],
#  ['oniichan'],
#  ['aniki'],
#  ['dunno', 'armor', 'pretti', 'scari'],
#  ['man',
#   'ochako',
#   'best',
#   'girl',
#   'made',
#   'signific',
#   'career',
#   'decis',
#   'becaus',
#   'compliment',
#   'old',
#   'childhood',
#   'nicknam',
#   'also',
#   'gran',
#   'torino',
#   'fuck',
#   'awesom'],
#  ['urav'],
#  ['boob',
#   'weird',
#   'though',
#   'cant',
#   'realli',
#   'put',
#   'into',
#   'word',
#   'feel',
#   'like'],
#  ['idea', 'look'],
#  ['arm', 'left', 'boob', 'right'],
#  ['not', 'see'],
#  ['take', 'much', 'bodi'],
#  ['date',
#   'girl',
#   'whose',
#   'boob',
#   'look',
#   'like',
#   'actual',
#   'pretti',
#   'normal',
#   'especi',
#   'theyr',
#   'larger',
#   'side'],
#  ['think',
#   'look',
#   'way',
#   'becaus',
#   'shirt',
#   'isnt',
#   'form',
#   'fit',
#   'hang',
#   'bit',
#   'also',
#   'may',
#   'short',
#   'torso',
#   'doesnt',
#   'seem',
#   'unrealist',
#   'anyth',
#   'bnha',
#   'girl',
#   'seem',
#   'more',
#   'realist',
#   'proport',
#   'most',
#   'show',
#   'seen'],
#  ['say', 'face'],
#  ['need',
#   'win',
#   'best',
#   'girl',
#   'contest',
#   'guy',
#   'pleas',
#   'vote',
#   'want',
#   'win'],
#  ['sorri', 'vote', 'megumi', 'kato', 'way'],
#  ['alreadi'],
#  ['wait'],
#  ['lost', 'last', 'round', 'illya', 'think'],
#  ['hell', 'illya'],
#  ['tragic', 'loli', 'bitch', 'ride'],
#  ['mayb',
#   'shell',
#   'better',
#   'luck',
#   'against',
#   'overthetop',
#   'memetast',
#   'explos',
#   'user',
#   'time'],
#  ['peopl', 'will', 'vote', 'trash', 'instead', 'best', 'girl', 'cant', 'help'],
#  ['tradit'],
#  ['damn', 'cute'],
#  ['hair', 'float', 'happi'],
#  ['unconsci',
#   'use',
#   'quirk',
#   'like',
#   'biribiri',
#   'releas',
#   'electr',
#   'get',
#   'angri'],
#  [],
#  [],
#  ['hinako', 'note', 'air', 'season', 'didnt', 'seem', 'get', 'much', 'attent'],
#  ['not', 'supris', 'given', 'mani', 'awesom', 'show', 'there', 'season'],
#  ['yeah', 'one', 'charact', 'eat', 'book'],
#  ['show', 'about'],
#  ['slice',
#   'life',
#   'about',
#   'girl',
#   'countrysid',
#   'want',
#   'run',
#   'theatr',
#   'club',
#   'citi',
#   'order',
#   'overcom',
#   'shyness',
#   'cgdct',
#   'shenanigan',
#   'decent',
#   'amount',
#   'fanservic',
#   'ensu'],
#  ['alright',
#   'ill',
#   'add',
#   'list',
#   'might',
#   'watch',
#   'look',
#   'someth',
#   'slice',
#   'life',
#   'bad',
#   'fanservic'],
#  ['bad',
#   'fanservic',
#   'think',
#   'fanservic',
#   'bad',
#   'dont',
#   'watch',
#   'there',
#   'quit',
#   'peopl',
#   'thought',
#   'there',
#   'way',
#   'much',
#   'term',
#   'anim',
#   'watch',
#   'kind',
#   'grew',
#   'ecchi',
#   'like',
#   'fanservic'],
#  ['limit',
#   'much',
#   'fine',
#   'around',
#   'fairi',
#   'tail',
#   'konosuba',
#   'amount',
#   'fanservic',
#   'much',
#   'wors',
#   'two',
#   'show',
#   'probabl',
#   'wont',
#   'watch'],
#  ['probabl',
#   'say',
#   'there',
#   'more',
#   'fanservic',
#   'hinako',
#   'note',
#   'two',
#   'fanservic',
#   'play',
#   'larger',
#   'role',
#   'hinako',
#   'note',
#   'there',
#   'definit',
#   'more',
#   'there',
#   'konosuba',
#   'think',
#   'possibl',
#   'compar',
#   'level',
#   'fanservic',
#   'fairi',
#   'tail',
#   'although',
#   'think',
#   'slightli',
#   'more',
#   'hinako'],
#  ['alright', 'thank', 'tell', 'about', 'even', 'dissuad', 'watch'],
#  ['youv', 'got', 'attent'],
#  ['thi', 'ship', 'sail', 'realli'],
#  ['well', 'horikoshi', 'said'],
#  ['late', 'repli', 'wait', 'realli'],
#  ['well',
#   'sure',
#   'obvious',
#   'main',
#   'coupl',
#   'ship',
#   'doesnt',
#   'feel',
#   'organ',
#   'one',
#   'gonna',
#   'support',
#   'much'],
#  ['wrong', 'gmo', 'ship', 'nicoisdon'],
#  ['ship',
#   'doesnt',
#   'feel',
#   'organ',
#   'one',
#   'gonna',
#   'support',
#   'much',
#   'dont',
#   'sure',
#   'arrow',
#   'exist'],
#  ['talk', 'about', 'organ', 'get'],
#  ['stay', 'away', 'guggenheim'],
#  ['tumblr', 'fangirl', 'realli', 'count', 'peopl', 'though'],
#  ['yeah', 'filthi', 'shipper', 'wer', 'noth', 'like'],
#  ['exactli',
#   'not',
#   'like',
#   'episod',
#   'discuss',
#   'thread',
#   'discuss',
#   'ship',
#   'more',
#   'actual',
#   'show',
#   'cough',
#   'kiznaiv',
#   'cough'],
#  ['kiznaiv', 'liter', 'made', 'diagram', 'els', 'were', 'suppos'],
#  ['kiznaiv', 'exactli'],
#  ['wev', 'never', 'best', 'ship', 'contest', 'anyth', 'like'],
#  ['dont', 'mean', 'felic', 'friend'],
#  ['season', 'amaz'],
#  ['dont', 'forget', 'watch', 'extra', 'scene', 'after'],
#  ['read',
#   'discuss',
#   'thread',
#   'while',
#   'credit',
#   'roll',
#   'usual',
#   'switch',
#   'soon',
#   'after',
#   'thank',
#   'save',
#   'bacon'],
#  ['like', 'gran', 'torino', 'voic', 'dub'],
#  ['hope', 'get', 'offer', 'good', 'agenc'],
#  ['there', 'extra', 'scene', 'like', 'after', 'everi', 'episod'],
#  ['show',
#   'occasion',
#   'recommend',
#   'check',
#   'after',
#   'sure',
#   'number',
#   'post',
#   'scene',
#   'miss',
#   'throughout',
#   'year',
#   'limitless'],
#  ['usual', 'tell', 'get', 'use', 'start', 'time', 'wise'],
#  ['yeah', 'coupl', 'think', 'there', 'one', 'last', 'time', 'well'],
#  ['there', 'last', 'includ', 'one'],
#  ['instruct', 'unclear', 'now', 'begun', 'bing', 'watch', 'everi', 'episod'],
#  ['nice',
#   'kirishima',
#   'manli',
#   'bakugo',
#   'like',
#   'deku',
#   'might',
#   'onesi',
#   'damn',
#   'ador',
#   'practic',
#   'heal'],
#  ['true', 'quirk', 'actual', 'manli'],
#  ['cant', 'stop', 'wont', 'stop'],
#  ['midnight',
#   'casual',
#   'enter',
#   'classroom',
#   'fill',
#   'adolesc',
#   'boy',
#   'while',
#   'flaunt',
#   'oppai',
#   'serious',
#   'though',
#   'love',
#   'show',
#   'tell',
#   'way',
#   'make',
#   'code',
#   'name',
#   'midorya',
#   'pick',
#   'deku',
#   'awesom',
#   'also',
#   'give',
#   'fodder',
#   'otp',
#   'sinc',
#   'uraraka',
#   'gave',
#   'midorya',
#   'posit',
#   'mean',
#   'deku',
#   'coolest',
#   'code',
#   'name',
#   'though',
#   'gotta',
#   'tokoyami',
#   'tsukoyomi',
#   'hope',
#   'doesnt',
#   'uchiha',
#   'edg',
#   'iida',
#   'definit',
#   'man',
#   'mission',
#   'lust',
#   'reveng',
#   'thi',
#   'shounen',
#   'not',
#   'scare',
#   'will',
#   'happen',
#   'man',
#   'omin',
#   'narrat',
#   'midorya',
#   'end',
#   'didnt',
#   'realli',
#   'make',
#   'feel',
#   'eas',
#   'about',
#   'come',
#   'gran',
#   'torino',
#   'look',
#   'pretti',
#   'intimid',
#   'preveiw',
#   'might',
#   'teacher',
#   'mean',
#   'one',
#   'also',
#   'definit',
#   'same',
#   'voic',
#   'shamisen',
#   'haruhui',
#   'agasa',
#   'case',
#   'close'],
#  ['tokoyami',
#   'boy',
#   'actual',
#   'gain',
#   'dark',
#   'power',
#   'never',
#   'stop',
#   'chuunibyo'],
#  ['ask',
#   'same',
#   'question',
#   'tokoyami',
#   'megumin',
#   'still',
#   'chuunibyo',
#   'power',
#   'claim'],
#  ['tsukuyomi',
#   'mean',
#   'guess',
#   'portmanteau',
#   'name',
#   'word',
#   'about',
#   'dark',
#   'shadow',
#   'night'],
#  ['tsukuyomi',
#   'moon',
#   'god',
#   'shinto',
#   'religion',
#   'which',
#   'appropri',
#   'sinc',
#   'tokoyami',
#   'power',
#   'stronger',
#   'night'],
#  ['amaz', 'simpl', 'geniu', 'best', 'bird', 'best'],
#  ['name',
#   'deeper',
#   'mean',
#   'horikoshi',
#   'clever',
#   'work',
#   'pun',
#   'into',
#   'name',
#   'both',
#   'hero',
#   'name',
#   'character',
#   'birth',
#   'name',
#   'look',
#   'pretti',
#   'much',
#   'character',
#   'name',
#   'find',
#   'mean',
#   'tokoyami',
#   'instanc',
#   'mean',
#   'etern',
#   'dark'],
#  ['man',
#   'fuck',
#   'love',
#   'name',
#   'actual',
#   'mean',
#   'arent',
#   'random',
#   'sound',
#   'cool'],
#  ['lord', 'explos', 'murder'],
#  ['more',
#   'exampl',
#   'find',
#   'these',
#   'trivia',
#   'section',
#   'bottom',
#   'character',
#   'page',
#   'bnha',
#   'wiki',
#   'name',
#   'uraraka',
#   'mean',
#   'bright',
#   'beauti',
#   'ochako',
#   'tea',
#   'child',
#   'tenya',
#   'name',
#   'come',
#   'idaten',
#   'mean',
#   'great',
#   'runner',
#   'final',
#   'exclamatori',
#   'particl',
#   'tsuyu',
#   'name',
#   'contain',
#   'kanji',
#   'frog',
#   'puff',
#   'japan',
#   'raini',
#   'humid',
#   'climat',
#   'latter',
#   'which',
#   'climat',
#   'dure',
#   'toad',
#   'egglay',
#   'season',
#   'denki',
#   'famili',
#   'name',
#   'contain',
#   'kanji',
# ...
#   'noth',
#   'about',
#   'mean',
#   'noth',
#   'dekiru',
#   'terribl',
#   'translat',
#   'part',
#   'subber',
#   'describ',
#   'said',
#   'which',
#   'along',
#   'line',
#   'give',
#   'feel',
#   'tri',
#   'one',
#   'best'],
#  ['huh',
#   'also',
#   'tri',
#   'listen',
#   'care',
#   'everi',
#   'time',
#   'play',
#   'flashback',
#   'episod',
#   'guess',
#   'there',
#   'noth',
#   'there'],
#  ['kinda',
#   'pointless',
#   'hero',
#   'name',
#   'univers',
#   'becaus',
#   'basic',
#   'broadcast',
#   'true',
#   'name',
#   'ident',
#   'world',
#   'see',
#   'call',
#   'code',
#   'name',
#   'instead',
#   'world',
#   'most',
#   'peopl',
#   'power',
#   'superhero',
#   'equival',
#   'cop',
#   'guess',
#   'author',
#   'chose',
#   'not',
#   'secret',
#   'ident',
#   'thing',
#   'power',
#   'differ',
#   'between',
#   'charact',
#   'wide',
#   'stronger',
#   'hero',
#   'villain',
#   'logic',
#   'use',
#   'famili',
#   'friend',
#   'weak'],
#  ['there',
#   'hero',
#   'name',
#   'univers',
#   'becaus',
#   'comic',
#   'tell',
#   'wouldnt',
#   'want',
#   'rad',
#   'hero',
#   'name',
#   'got',
#   'power',
#   'secret',
#   'ident',
#   'not',
#   'hero',
#   'name',
#   'about',
#   'requir',
#   'flashi',
#   'costum',
#   'useless',
#   'cape'],
#  ['hero',
#   'code',
#   'name',
#   'inunivers',
#   'brand',
#   'merchandis',
#   'rememb',
#   'major',
#   'hero',
#   'bnha',
#   'fame',
#   'money',
#   'hero',
#   'name',
#   'move',
#   'name',
#   'form',
#   'name',
#   'add',
#   'hero',
#   'popular',
#   'alway',
#   'look',
#   'episod',
#   'despit',
#   'fairli',
#   'new',
#   'hero',
#   'upandcom',
#   'kamui',
#   'special',
#   'move',
#   'preempt',
#   'bind',
#   'lacquer',
#   'chain',
#   'prison',
#   'well',
#   'known',
#   'hero',
#   'fanboy',
#   'izuku',
#   'much',
#   'chant',
#   'attack',
#   'see',
#   'izuku',
#   'buy',
#   'some',
#   'kamui',
#   'merchandis',
#   'attack',
#   'name',
#   'slap',
#   'everyon',
#   'bnha',
#   'should',
#   'regist',
#   'publicli',
#   'hero',
#   'villain',
#   'civilian',
#   'alik',
#   'due',
#   'advent',
#   'quirk',
#   'potenti',
#   'devast',
#   'bring',
#   'societi',
#   'everyon',
#   'know',
#   'everyon',
#   'famili',
#   'easili',
#   'research',
#   'sure',
#   'goe',
#   'both',
#   'hero',
#   'villain',
#   'apart',
#   'peopl',
#   'like',
#   'shigaraki',
#   'some',
#   'unknown',
#   'reason',
#   'isnt',
#   'quirk',
#   'registri'],
#  ['ahh',
#   'make',
#   'sens',
#   'impress',
#   'live',
#   'govern',
#   'salari',
#   'instead',
#   'like',
#   'tiger',
#   'bunni',
#   'mayb',
#   'mix',
#   'govern',
#   'salari',
#   'outsid',
#   'merch',
#   'incom',
#   'still',
#   'regist',
#   'everyon',
#   'one',
#   'thing',
#   'make',
#   'inform',
#   'public',
#   'anoth',
#   'put',
#   'hero',
#   'disadvantag',
#   'hero',
#   'not',
#   'take',
#   'peopl',
#   'hostag',
#   'villain'],
#  ['yeah',
#   'exactli',
#   'mix',
#   'get',
#   'paid',
#   'salari',
#   'higherrank',
#   'hero',
#   'get',
#   'paid',
#   'more',
#   'rank',
#   'decid',
#   'number',
#   'factor',
#   'popular',
#   'one',
#   'brand',
#   'market',
#   'huge',
#   'while',
#   'act',
#   'own',
#   'sourc',
#   'incom',
#   'also',
#   'dictat',
#   'government',
#   'salari',
#   'not',
#   'necessarili',
#   'major',
#   'villain',
#   'thing',
#   'peopl',
#   'care',
#   'about',
#   'hero',
#   'deduc',
#   'true',
#   'ident',
#   'normal',
#   'appear',
#   'quirk',
#   'theyr',
#   'abl',
#   'bargain',
#   'thing',
#   'use',
#   'pawn',
#   'mental',
#   'game',
#   'get',
#   'villain',
#   'lose',
#   'will',
#   'fight',
#   'knowledg',
#   'power',
#   'after'],
#  ['get',
#   'explain',
#   'arc',
#   'besid',
#   'whole',
#   'stain',
#   'thing',
#   'hero',
#   'oper',
#   'main',
#   'part',
#   'field',
#   'train'],
#  ['wait',
#   'skip',
#   'convers',
#   'between',
#   'shoto',
#   'mother',
#   'pass',
#   'good',
#   'opportun',
#   'charact',
#   'develop',
#   'also',
#   'mani',
#   'episod',
#   'look',
#   'until',
#   'reach',
#   'fight',
#   'hero',
#   'killer',
#   'stain'],
#  ['remov'],
#  ['dude', 'spoiler', 'tag'],
#  ['dont',
#   'know',
#   'tag',
#   'phone',
#   'delet',
#   'part',
#   'probabl',
#   'meant',
#   'spoiler'],
#  ['becaus',
#   'show',
#   'straight',
#   'constru',
#   'hamfist',
#   'after',
#   'privat',
#   'convers',
#   'between',
#   'mother',
#   'son',
#   'privat',
#   'like',
#   'watcher',
#   'reader',
#   'dont',
#   'need',
#   'see',
#   'convers',
#   'good',
#   'charact',
#   'develop',
#   'take',
#   'place',
#   'trust',
#   'there',
#   'good',
#   'stuff',
#   'come',
#   'todoroki'],
#  ['becaus',
#   'show',
#   'straight',
#   'constru',
#   'hamfist',
#   'after',
#   'privat',
#   'convers',
#   'between',
#   'mother',
#   'son',
#   'privat',
#   'like',
#   'watcher',
#   'reader',
#   'realis',
#   'isnt',
#   'real',
#   'life',
#   'lol'],
#  ['henc', 'genuin', 'implic', 'though', 'believ', 'not'],
#  ['well',
#   'still',
#   'possibl',
#   'shove',
#   'somewher',
#   'later',
#   'honestli',
#   'hope',
#   'dont',
#   'becaus',
#   'weird',
#   'place',
#   'put',
#   'make',
#   'sens',
#   'way',
#   'becaus',
#   'learn',
#   'move',
#   'situat',
#   'show'],
#  ['becaus',
#   'show',
#   'straight',
#   'constru',
#   'hamfist',
#   'thi',
#   'alreadi',
#   'know',
#   'end',
#   'last',
#   'episod',
#   'convers',
#   'like',
#   'wouldv',
#   'gone',
#   'actual',
#   'show',
#   'redund',
#   'glad',
#   'show',
#   'valu',
#   'viewer',
#   'intellig',
#   'cut',
#   'thing',
#   'audienc',
#   'easili',
#   'infer'],
#  ['exactli', 'both', 'horikoshi', 'bone', 'adapt', 'respect', 'way'],
#  ['fuck',
#   'dont',
#   'rememb',
#   'atmospher',
#   'dull',
#   'tens',
#   'manga',
#   'edit',
#   'think',
#   'dull',
#   'wrong',
#   'word',
#   'sorri',
#   'about'],
#  ['wanna', 'fuck', 'uraraka'],
#  ['relax', 'buddi', 'grade'],
#  ['theyr', 'grade', 'like', 'also', 'isnt', 'real'],
#  ['yeah', 'probabl', 'alreadi', 'old', 'sound'],
#  ['were', 'not', 'meant', 'get', 'new', 'open', 'today'],
#  ['catch', 'glimps', 'toho', 'anim', 'youtub'],
#  ['after', 'break'],
#  ['thought', 'there', 'suppos', 'new', 'start', 'episod'],
#  ['week', 'after', 'there', 'break', 'next', 'week'],
#  ['start', 'episod', 'juli', 'after', 'oneweek', 'break'],
#  ['thought', 'get', 'new'],
#  ['new', 'debut', 'new', 'arc', 'start', 'episod'],
#  ['thought', 'firtst', 'episod', 'new', 'arc'],
#  ['not', 'realli', 'transit', 'episod', 'between', 'arc'],
#  ['yeeeee', 'grand', 'torino', 'time'],
#  ['anyon',
#   'tell',
#   'mani',
#   'episod',
#   'there',
#   'season',
#   'wiki',
#   'imdb',
#   'show',
#   'last',
#   'episod',
#   'air',
#   'june',
#   'quit',
#   'while'],
#  [],
#  ['episod', 'will', 'season', 'final', 'thank'],
#  ['exactli', 'there', 'episod', 'next', 'week', 'therel', 'more', 'total'],
#  ['wonder', 'far', 'take', 'season', 'relat', 'manga'],
#  ['wiat', 'miss', 'not', 'actual', 'say', 'bakugo', 'hero', 'name'],
#  ['still', 'hasnt', 'chosen', 'one'],
#  ['thought',
#   'were',
#   'get',
#   'new',
#   'next',
#   'episod',
#   'guess',
#   'week',
#   'break',
#   'right',
#   'next',
#   'episod',
#   'juli',
#   'long',
#   'time',
#   'wait',
#   'more',
#   'plu',
#   'ultra'],
#  ['nope', 'one', 'week', 'break', 'next', 'episod', 'air', 'new'],
#  ['scene',
#   'kid',
#   'midorya',
#   'mom',
#   'much',
#   'heart',
#   'iida',
#   'dont',
#   'like',
#   'foreshadow',
#   'might',
#   'happen'],
#  ['two',
#   'nitpick',
#   'kinda',
#   'bullshit',
#   'peopl',
#   'got',
#   'job',
#   'offer',
#   'sort',
#   'through',
#   'shit',
#   'themselv',
#   'decid',
#   'which',
#   'pick',
#   'day',
#   'kinda',
#   'surpris',
#   'endeavour',
#   'didnt',
#   'throw',
#   'weight',
#   'around',
#   'ensur',
#   'agenc',
#   'offer',
#   'todoroki',
#   'got',
#   'consid',
#   'entir',
#   'goal',
#   'not',
#   'choos',
#   'offer'],
#  ['not',
#   'hard',
#   'research',
#   'top',
#   'hero',
#   'agenc',
#   'youd',
#   'realli',
#   'like',
#   'hero',
#   'realli',
#   'want',
#   'work',
#   'check',
#   'see',
#   'sent',
#   'offer',
#   'narrow',
#   'down',
#   'there',
#   'becom',
#   'becom',
#   'without',
#   'much',
#   'effort'],
#  ['babi', 'deku', 'cute', 'super'],
#  ['froppi'],
#  ['definit',
#   'look',
#   'forward',
#   'next',
#   'week',
#   'episod',
#   'after',
#   'watch',
#   'one',
#   'alway',
#   'love',
#   'train',
#   'moment',
#   'best',
#   'edit',
#   'realiz',
#   'there',
#   'gonna',
#   'week',
#   'break',
#   'sad',
#   'time'],
#  ['much',
#   'silli',
#   'kacchan',
#   'sound',
#   'offici',
#   'hero',
#   'name',
#   'might',
#   'actual',
#   'pick',
#   'good',
#   'name',
#   'bakug',
#   'someth',
#   'explosionrel',
#   'though',
#   'like',
#   'dynamit',
#   'nitro',
#   'nitrogen'],
#  ['about', 'dynamight'],
#  ['manga', 'spoiler', 'still', 'hope', 'ground', 'zero', 'becom', 'thing'],
#  ['hero', 'academia', 'lit'],
#  ['flashback', 'midoriya', 'mom', 'feel', 'urav', 'best', 'name'],
#  ['bakug',
#   'best',
#   'king',
#   'explos',
#   'murder',
#   'king',
#   'explodokil',
#   'better',
#   'also',
#   'red',
#   'riot',
#   'great',
#   'name',
#   'kirishima',
#   'cant',
#   'wait',
#   'see',
#   'more',
#   'bakug',
#   'kirishima',
#   'friendship',
#   'futur',
#   'episod'],
#  ['mofuckin',
#   'gran',
#   'torino',
#   'arriv',
#   'cant',
#   'wait',
#   'see',
#   'give',
#   'deku',
#   'some',
#   'lesson',
#   'about',
#   'quirk',
#   'thi',
#   'next',
#   'arc',
#   'hype',
#   'not',
#   'forget',
#   'about',
#   'bnha',
#   'spoiler',
#   'deku',
#   'full',
#   'cowl',
#   'also',
#   'until',
#   'next',
#   'episod',
#   'everyon'],
#  ['train', 'deku', 'chair', 'real', 'thing'],
#  ['basic',
#   'instead',
#   'sit',
#   'chair',
#   'hover',
#   'over',
#   'slightli',
#   'yeah',
#   'real',
#   'thing'],
#  ['entir', 'class', 'holi', 'shit'],
#  [],
#  ['think', 'pretti', 'much', 'modifi', 'wallsit'],
#  ['lida', 'deserv', 'better'],
#  ['iida', 'there'],
#  ['wait', 'thought', 'there', 'wasnt', 'episod', 'week'],
#  ['great',
#   'tragedi',
#   'happen',
#   'today',
#   'now',
#   'realiz',
#   'sung',
#   'new',
#   'favorit',
#   'band',
#   'littl',
#   'glee',
#   'monster',
#   'music',
#   'bit',
#   'differ',
#   'usual',
#   'check',
#   'latest',
#   'album',
#   'joy',
#   'monster',
#   'amaz',
#   'also',
#   'ball',
#   'cover',
#   'septemb',
#   'earth',
#   'wind',
#   'fire'],
#  ['get', 'feel', 'someth', 'bad', 'happen', 'iida', 'keepiidasaf'],
#  ['todoroki', 'hero', 'name', 'todoroki'],
#  ['midoriya',
#   'look',
#   'more',
#   'jack',
#   'normal',
#   'preview',
#   'while',
#   'wear',
#   'slightli',
#   'differ',
#   'uniform',
#   'super',
#   'excit',
#   'see',
#   'train',
#   'gran',
#   'torino'],
#  ['anyon',
#   'abl',
#   'explain',
#   'deku',
#   'mean',
#   'fit',
#   'hero',
#   'name',
#   'get',
#   'insult',
#   'use',
#   'call',
#   'also',
#   'mayb',
#   'anoth',
#   'mean'],
#  ['deku',
#   'meant',
#   'insult',
#   'which',
#   'mean',
#   'someon',
#   'useless',
#   'cant',
#   'anyth',
#   'dure',
#   'season',
#   'anim',
#   'ochako',
#   'said',
#   'deku',
#   'sound',
#   'like',
#   'dekiru',
#   'which',
#   'mean',
#   'izuku',
#   'base',
#   'new',
#   'mean',
#   'deku'],
#  ['awesom',
#   'episod',
#   'wish',
#   'there',
#   'enough',
#   'materi',
#   'get',
#   'least',
#   'episod'],
#  ['urav',
#   'realli',
#   'awesom',
#   'name',
#   'made',
#   'hype',
#   'dont',
#   'know',
#   'not',
#   'even',
#   'teacher',
#   'someth',
#   'stop',
#   'iida',
#   'mean',
#   'pretti',
#   'obviou',
#   'after',
#   'hero',
#   'killer',
#   'anoth',
#   'note',
#   'ill',
#   'realli',
#   'miss',
#   'realli',
#   'got',
#   'use',
#   'hope',
#   'new',
#   'one',
#   'will',
#   'good',
#   'well',
#   'plu',
#   'ultra'],
#  ['seem',
#   'like',
#   'way',
#   'loop',
#   'suppos',
#   'air',
#   'third',
#   'season',
#   'start',
#   'next',
#   'week',
#   'there',
#   'announc',
#   'date',
#   'suppos',
#   'air',
#   'still',
#   'part',
#   'second',
#   'season'],
#  ['nvm', 'got', 'answer', 'anoth', 'post'],
#  ['thi',
#   'show',
#   'stereoyp',
#   'shoen',
#   'anim',
#   'well',
#   'ochaco',
#   'preciou',
#   'must',
#   'protect',
#   'midoriya',
#   'deku',
#   'becaus',
#   'made',
#   'heart',
#   'burst'],
#  ['chapter'],
#  ['assum', 'watch', 'snippet', 'past', 'pick', 'right'],
#  ['doe', 'anim', 'cover', 'lot', 'manga'],
#  ['faith', 'adapt', 'cover', 'everyth'],
#  ['season', 'final', 'not', 'know', 'mani', 'more', 'there', 'left', 'season'],
#  ['episod',
#   'next',
#   'week',
#   'return',
#   'anoth',
#   'cour',
#   'like',
#   'more',
#   'episod'],
#  ['quit', 'sad', 'see', 'tenya', 'not', 'take', 'ingenium', 'hero', 'name'],
#  ['cour', 'preview', 'might', 'miss', 'includ', 'new', 'song'],
#  ['next', 'episod', 'hyyyyyyyyyyyyyyyyyp'],
#  ['say',
#   'arc',
#   'will',
#   'much',
#   'hype',
#   'mostli',
#   'becaus',
#   'main',
#   'focu',
#   'growth',
#   'side',
#   'note',
#   'love',
#   'growth',
#   'like',
#   'madman'],
#  ['bakugo', 'think', 'name', 'end', 'manga', 'spoiler', 'welcom'],
#  ['feel', 'like', 'tenya', 'will', 'becom', 'villain'],
#  ['gran',
#   'torino',
#   'saitama',
#   'one',
#   'punch',
#   'man',
#   'look',
#   'like',
#   'bro',
#   'same',
#   'costum',
#   'design',
#   'bit',
#   'like',
#   'kirishima',
#   'tetsutetsu',
#   'tetsutetsu'],
#  ['gonna', 'call', 'bet', 'bakgo', 'hero', 'name', 'will', 'end', 'kacchan'],
#  ['iida',
#   'becom',
#   'villain',
#   'least',
#   'start',
#   'villain',
#   'thing',
#   'call',
#   'now'],
#  ['cannot', 'stop', 'twinkl'],
#  ['gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata',
#   'gata'],
#  ['anyon',
#   'els',
#   'littl',
#   'peev',
#   'super',
#   'hero',
#   'name',
#   'anyth',
#   'certain',
#   'hide',
#   'properti',
#   'quirk',
#   'best',
#   'fight',
#   'enemi',
#   'doesnt',
#   'know',
#   'fight',
#   'defend',
#   'dont',
#   'know',
#   'will',
#   'attack',
#   'give',
#   'away',
#   'hero',
#   'name',
#   'seem',
#   'kind',
#   'disadvantag',
#   'also',
#   'villain',
#   'same',
#   'whi',
#   'realli',
#   'like',
#   'deku',
#   'mean',
#   'doesnt',
#   'give',
#   'anyth',
#   'away',
#   'about'],
#  ['thing',
#   'probabl',
#   'everybodi',
#   'alreadi',
#   'quirk',
#   'expos',
#   'reveal',
#   'thi',
#   'advantag',
#   'someth',
#   'villain',
#   'possess'],
#  ['super',
#   'late',
#   'post',
#   'like',
#   'bakog',
#   'hand',
#   'back',
#   'paper',
#   'deku',
#   'wasnt',
#   'rude'],
#  ['swear',
#   'boku',
#   'hero',
#   'best',
#   'charact',
#   'creation',
#   'uniqu',
#   'cool',
#   'look',
#   'besid',
#   'interest',
#   'see',
#   'might',
#   'teacher',
#   'import'],
#  ['even',
#   'read',
#   'manga',
#   'anim',
#   'great',
#   'feel',
#   'like',
#   'first',
#   'time',
#   'see',
#   'doesn',
#   'feel',
#   'like',
#   'know',
#   'happen',
#   'next',
#   'frick',
#   'awesom',
#   'nice',
#   'job',
#   'bone',
#   'sad',
#   'midnight',
#   'didnt',
#   'like',
#   'masterpic',
#   'codenam',
#   'king',
#   'explos',
#   'murder',
#   'mean',
#   'awesom',
#   'right'],
#  ['bah',
#   'one',
#   'student',
#   'internship',
#   'want',
#   'hear',
#   'among',
#   'didnt',
#   'show',
#   'invis',
#   'girl',
#   'quirk',
#   'come',
#   'into',
#   'good',
#   'use',
#   'while',
#   'seem',
#   'somewhat',
#   'decent',
#   'shape',
#   'doubt',
#   'shed',
#   'good',
#   'fight',
#   'villain',
#   'like',
#   'urav',
#   'intern',
#   'similarli',
#   'dont',
#   'see',
#   'much',
#   'use',
#   'emerg',
#   'servic',
#   'likewis',
#   'mineta',
#   'use',
#   'quirk',
#   'use',
#   'climb',
#   'stuff',
#   'prevent',
#   'peopl',
#   'run',
#   'hero',
#   'doesnt',
#   'strike',
#   'one',
#   'will',
#   'far',
#   'will',
#   'probabl',
#   'get',
#   'beaten',
#   'pulp',
#   'women',
#   'pervy',
#   'doubt',
#   'actual',
#   'perform',
#   'adequ',
#   'previous',
#   'mention',
#   'activ',
#   'partli',
#   'becaus',
#   'sight',
#   'danger',
#   'even',
#   'not',
#   'direct',
#   'turn',
#   'into',
#   'shiver',
#   'mess',
#   'trembl',
#   'also',
#   'deal',
#   'number',
#   'briefcas',
#   'figur',
#   'number',
#   'class'],
#  ['quirk',
#   'come',
#   'into',
#   'good',
#   'use',
#   'manga',
#   'abil',
#   'also',
#   'includ',
#   'light',
#   'manipul'],
#  ['spoiler',
#   'mate',
#   'quirk',
#   'wasnt',
#   'actual',
#   'explain',
#   'until',
#   'not',
#   'recent'],
#  ['nvisibl',
#   'girl',
#   'quirk',
#   'come',
#   'into',
#   'good',
#   'use',
#   'while',
#   'seem',
#   'somewhat',
#   'decent',
#   'shape',
#   'doubt',
#   'shed',
#   'good',
#   'fight',
#   'villain',
#   'like',
#   'urav',
#   'intern',
#   'similarli',
#   'dont',
#   'see',
#   'much',
#   'use',
#   'emerg',
#   'servic',
#   'imagin',
#   'there',
#   'probabl',
#   'evil',
#   'organis',
#   'specialis',
#   'infiltr',
#   'spi',
#   'mayb',
#   'even',
#   'sabotag',
#   'death',
#   'laser',
#   'shed',
#   'actual',
#   'realli',
#   'fuck',
#   'good',
#   'sidekick',
#   'becaus',
#   'distract',
#   'villian',
#   'got',
#   'open',
#   'goal',
#   'likewis',
#   'mineta',
#   'use',
#   'quirk',
#   'use',
#   'climb',
#   'stuff',
#   'prevent',
#   'peopl',
#   'run',
#   'hero',
#   'doesnt',
#   'strike',
#   'one',
#   'will',
#   'far',
#   'yeah',
#   'tbf',
#   'quirk',
#   'actual',
#   'realli',
#   'use',
#   'far',
#   'came',
#   'handi',
#   'villian',
#   'fight',
#   'use',
#   'take',
#   'down',
#   'runner',
#   'race',
#   'think',
#   'versatil',
#   'strong',
#   'point',
#   'hed',
#   'definit',
#   'good',
#   'support',
#   'combat',
#   'rescu',
#   'cant',
#   'realli',
#   'see',
#   'ever',
#   'break',
#   'own',
#   'though'],
#  ['pinki', 'great', 'guy']]

# %%
x = "abc.json"
x.split(".")[0]
# Out:
# 'abc'
